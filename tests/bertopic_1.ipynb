# %%
import os
import sqlite3 
from bertopic import BERTopic

# Connection to database file
db_dir = os.path.abspath("/home/ematos/devel/kardec/kardec_laravel/database")
database_file = os.path.join(db_dir, "dataset.txtai.sqlite3")

db = sqlite3.connect(database_file)
cur = db.cursor()

rows = cur.execute("SELECT sentence as text from sentence").fetchall()
sentences = []
for row in rows:
  sentences.append(row[0])
#print(sentences)

topic_model = BERTopic("Portuguese")
topics, probs = topic_model.fit_transform(sentences)

# %%
topic_model.get_topic_info()
# Out:
#     Topic  Count                                   Name  \
# 0      -1   2013                       -1_que_de_não_se
# 1       0    143             0_feira_dia_domingo_amanhã
# 2       1     92        1_francos_dinheiro_preço_quanto
# 3       2     86  2_espíritos_espiritismo_os_superiores
# 4       3     86                    3_ela_muito_que_não
# ..    ...    ...                                    ...
# 68     67     12          67_educação_crianças_já_vocês
# 69     68     12     68_sim_pergunta_resposta_perguntas
# 70     69     12      69_bordeaux_angély_angoulême_jean
# 71     70     11    70_enigma_esclareço_note_pseudônimo
# 72     71     10           71_fruto_flores_jardim_olhos
#
#                                        Representation  \
# 0       [que, de, não, se, para, em, ele, do, da, me]
# 1   [feira, dia, domingo, amanhã, no, segunda, na,...
# 2   [francos, dinheiro, preço, quanto, 100, mil, s...
# 3   [espíritos, espiritismo, os, superiores, dos, ...
# 4   [ela, muito, que, não, la, uma, com, me, acide...
# ..                                                ...
# 68  [educação, crianças, já, vocês, estudos, estud...
# 69  [sim, pergunta, resposta, perguntas, você, fal...
# 70  [bordeaux, angély, angoulême, jean, saint, poi...
# 71  [enigma, esclareço, note, pseudônimo, repetimo...
# 72  [fruto, flores, jardim, olhos, enquanto, adver...
#
#                                   Representative_Docs
# 0   [Seu filho, como sabe, veio me ver e foi um pr...
# 1   [No sábado da tua partida, às 16 horas, o tamb...
# 2   [Nada ainda foi feito quanto à partilha da dív...
# 3   [24 de janeiro de 1865  Médium: senhor Rul  Ev...
# 4   [A nova professora assistente entrou; mas não ...
# ..                                                ...
# 68  [Paro por aqui, minhas crianças, pois talvez j...
# 69  [Pergunta: Você está aí?  Resposta: Sim, fale ...
# 70  [Voltando de Bordeaux, prometi parar em Angoul...
# 71  [Mas eis a solução do enigma., Vamos, pecado, ...
# 72  [Não seremos mais felizes com nossos campos, q...
#
# [73 rows x 5 columns]

# %%
topic_model.get_topic(71)
# Out:
# [('fruto', np.float64(0.053027720811499)),
#  ('flores', np.float64(0.053027720811499)),
#  ('jardim', np.float64(0.0447007571481543)),
#  ('olhos', np.float64(0.04028739360631496)),
#  ('enquanto', np.float64(0.03904476903452987)),
#  ('adverso', np.float64(0.035364443577743175)),
#  ('carvalho', np.float64(0.035364443577743175)),
#  ('cachos', np.float64(0.035364443577743175)),
#  ('bonitas', np.float64(0.035364443577743175)),
#  ('arranjam', np.float64(0.035364443577743175))]

# %%
topic_model.get_document_info(sentences)
# Out:
#                                                Document  Topic  \
# 0     Senhor Pâtier,  Tenho a honra de lhe enviar an...     23
# 1     Eu me recordarei sempre que é ao senhor que de...      4
# 2     Uma vez adentrado nesta via, logo entrevi ness...     -1
# 3     Eu os fiz com consciência e perseverança, sob ...     -1
# 4     Encorajado por verdadeiros e sinceros adeptos,...     -1
# ...                                                 ...    ...
# 4294  Coragem, valentes soldados do Espiritismo, mar...      2
# 4295  É a estrela dos Magos que você carrega e que g...     -1
# 4296  Sua tarefa é gloriosa, não sem perigo para alg...     -1
# 4297  Mas conquistar sem perigo é triunfar sem glória”.     -1
# 4298  Você carrega a cruz, não para levar a vítima i...      4
#
#                                        Name  \
# 0            23_revista_livros_livro_senhor
# 1               4_deus_da_doutrina_caridade
# 2                          -1_que_de_não_se
# 3                          -1_que_de_não_se
# 4                          -1_que_de_não_se
# ...                                     ...
# 4294  2_espíritos_espiritismo_os_superiores
# 4295                       -1_que_de_não_se
# 4296                       -1_que_de_não_se
# 4297                       -1_que_de_não_se
# 4298            4_deus_da_doutrina_caridade
#
#                                          Representation  \
# 0     [revista, livros, livro, senhor, médiuns, assi...
# 1     [deus, da, doutrina, caridade, os, vos, todos,...
# 2         [que, de, não, se, para, em, ele, do, da, me]
# 3         [que, de, não, se, para, em, ele, do, da, me]
# 4         [que, de, não, se, para, em, ele, do, da, me]
# ...                                                 ...
# 4294  [espíritos, espiritismo, os, superiores, dos, ...
# 4295      [que, de, não, se, para, em, ele, do, da, me]
# 4296      [que, de, não, se, para, em, ele, do, da, me]
# 4297      [que, de, não, se, para, em, ele, do, da, me]
# 4298  [deus, da, doutrina, caridade, os, vos, todos,...
#
#                                     Representative_Docs  \
# 0     [Senhor,  Conhecendo sua simpatia, se não por ...
# 1     [Vamos, meus amigos, vocês que sabem, vocês qu...
# 2     [Seu filho, como sabe, veio me ver e foi um pr...
# 3     [Seu filho, como sabe, veio me ver e foi um pr...
# 4     [Seu filho, como sabe, veio me ver e foi um pr...
# ...                                                 ...
# 4294  [24 de janeiro de 1865  Médium: senhor Rul  Ev...
# 4295  [Seu filho, como sabe, veio me ver e foi um pr...
# 4296  [Seu filho, como sabe, veio me ver e foi um pr...
# 4297  [Seu filho, como sabe, veio me ver e foi um pr...
# 4298  [Vamos, meus amigos, vocês que sabem, vocês qu...
#
#                                             Top_n_words  Probability  \
# 0     revista - livros - livro - senhor - médiuns - ...     0.921684
# 1     deus - da - doutrina - caridade - os - vos - t...     0.604951
# 2     que - de - não - se - para - em - ele - do - d...     0.000000
# 3     que - de - não - se - para - em - ele - do - d...     0.000000
# 4     que - de - não - se - para - em - ele - do - d...     0.000000
# ...                                                 ...          ...
# 4294  espíritos - espiritismo - os - superiores - do...     1.000000
# 4295  que - de - não - se - para - em - ele - do - d...     0.000000
# 4296  que - de - não - se - para - em - ele - do - d...     0.000000
# 4297  que - de - não - se - para - em - ele - do - d...     0.000000
# 4298  deus - da - doutrina - caridade - os - vos - t...     1.000000
#
#       Representative_document
# 0                       False
# 1                       False
# 2                       False
# 3                       False
# 4                       False
# ...                       ...
# 4294                    False
# 4295                    False
# 4296                    False
# 4297                    False
# 4298                    False
#
# [4299 rows x 8 columns]

# %%
from bertopic.representation import KeyBERTInspired

# Fine-tune your topic representations
representation_model = KeyBERTInspired()
topic_model = BERTopic(representation_model=representation_model)

# %%
topics, probs = topic_model.fit_transform(sentences)

# %%
topic_model.get_topic_info()
# Out:
#     Topic  Count                                               Name  \
# 0      -1   2114                            -1_esto_como_isso_muito
# 1       0    162                             0_paris_1863_1862_1868
# 2       1    148                     1_carto_carta_cartas_comunicao
# 3       2     93                 2_fluido_estudo_pensamento_fluidos
# 4       3     79    3_espiritismo_humanidade_espirituais_espiritual
# ..    ...    ...                                                ...
# 66     65     11                   65_paris_sociedade_parisiense_de
# 67     66     11  66_mediunidade_corporal_classificaremos_indivi...
# 68     67     11                           67_carrre_tua_adeus_toda
# 69     68     11      68_davenport_supostamente_ciente_desencantado
# 70     69     10    69_perfeitamente_prontamente_gracioso_brevidade
#
#                                        Representation  \
# 0   [esto, como, isso, muito, eles, estou, ela, es...
# 1   [paris, 1863, 1862, 1868, 1865, 1864, 1873, st...
# 2   [carto, carta, cartas, comunicao, senhor, obri...
# 3   [fluido, estudo, pensamento, fluidos, influenc...
# 4   [espiritismo, humanidade, espirituais, espirit...
# ..                                                ...
# 66  [paris, sociedade, parisiense, de, estudos, ja...
# 67  [mediunidade, corporal, classificaremos, indiv...
# 68  [carrre, tua, adeus, toda, amiga, melhor, amli...
# 69  [davenport, supostamente, ciente, desencantado...
# 70  [perfeitamente, prontamente, gracioso, brevida...
#
#                                   Representative_Docs
# 0   [Espero que, a exemplo de suas antigas colegas...
# 1   [1 Paris, 14 de setembro de 1863., Paris, 18 d...
# 2   [Senhora,  Recebi a carta que a senhora me deu...
# 3   [Essas duas primeiras categorias são o efeito ...
# 4   [O Espiritismo não disse ainda e não deve ter ...
# ..                                                ...
# 66  [Sociedade de Paris., Sociedade de Paris., A S...
# 67  [Vemos nessa mediunidade que o encarnado muita...
# 68  [Adeus, boa Amélie., Toda tua,  Amélie., Tua m...
# 69  [Um espectador, insatisfeito com a ajuda dos v...
# 70  [O comboio do correio de Tours para Orléans po...
#
# [71 rows x 5 columns]

# %%
topic_model.get_topic(2)
# Out:
# [('fluido', np.float32(0.51907)),
#  ('estudo', np.float32(0.46663293)),
#  ('pensamento', np.float32(0.45214316)),
#  ('fluidos', np.float32(0.45080894)),
#  ('influenciado', np.float32(0.4165058)),
#  ('espirituais', np.float32(0.41531897)),
#  ('efeito', np.float32(0.40531164)),
#  ('esprito', np.float32(0.35507214)),
#  ('espiritual', np.float32(0.35500342)),
#  ('como', np.float32(0.34802774))]

# %%
topic_model.get_document_info(sentences)
# Out:
#                                                Document  Topic  \
# 0     Senhor Pâtier,  Tenho a honra de lhe enviar an...     13
# 1     Eu me recordarei sempre que é ao senhor que de...     20
# 2     Uma vez adentrado nesta via, logo entrevi ness...     51
# 3     Eu os fiz com consciência e perseverança, sob ...     -1
# 4     Encorajado por verdadeiros e sinceros adeptos,...     -1
# ...                                                 ...    ...
# 4294  Coragem, valentes soldados do Espiritismo, mar...      3
# 4295  É a estrela dos Magos que você carrega e que g...     21
# 4296  Sua tarefa é gloriosa, não sem perigo para alg...     -1
# 4297  Mas conquistar sem perigo é triunfar sem glória”.     -1
# 4298  Você carrega a cruz, não para levar a vítima i...     -1
#
#                                                  Name  \
# 0         13_sensibilizanos_senhor_recebemos_expresso
# 1             20_propagao_significado_latindo_insisto
# 2              51_estrangeira_novidades_descendo_logo
# 3                             -1_esto_como_isso_muito
# 4                             -1_esto_como_isso_muito
# ...                                               ...
# 4294  3_espiritismo_humanidade_espirituais_espiritual
# 4295           21_falaremos_esprito_escravos_espritos
# 4296                          -1_esto_como_isso_muito
# 4297                          -1_esto_como_isso_muito
# 4298                          -1_esto_como_isso_muito
#
#                                          Representation  \
# 0     [sensibilizanos, senhor, recebemos, expresso, ...
# 1     [propagao, significado, latindo, insisto, prej...
# 2     [estrangeira, novidades, descendo, logo, junta...
# 3     [esto, como, isso, muito, eles, estou, ela, es...
# 4     [esto, como, isso, muito, eles, estou, ela, es...
# ...                                                 ...
# 4294  [espiritismo, humanidade, espirituais, espirit...
# 4295  [falaremos, esprito, escravos, espritos, esfor...
# 4296  [esto, como, isso, muito, eles, estou, ela, es...
# 4297  [esto, como, isso, muito, eles, estou, ela, es...
# 4298  [esto, como, isso, muito, eles, estou, ela, es...
#
#                                     Representative_Docs  \
# 0     [No aguardo, aceite, senhor, a expressão de me...
# 1     [Este trabalho, útil ao desenvolvimento da dou...
# 2     [Espírito muito avançado que logo regressará a...
# 3     [Espero que, a exemplo de suas antigas colegas...
# 4     [Espero que, a exemplo de suas antigas colegas...
# ...                                                 ...
# 4294  [O Espiritismo não disse ainda e não deve ter ...
# 4295  [Consequentemente, é necessário definir o tom ...
# 4296  [Espero que, a exemplo de suas antigas colegas...
# 4297  [Espero que, a exemplo de suas antigas colegas...
# 4298  [Espero que, a exemplo de suas antigas colegas...
#
#                                             Top_n_words  Probability  \
# 0     sensibilizanos - senhor - recebemos - expresso...     0.788745
# 1     propagao - significado - latindo - insisto - p...     0.875423
# 2     estrangeira - novidades - descendo - logo - ju...     1.000000
# 3     esto - como - isso - muito - eles - estou - el...     0.000000
# 4     esto - como - isso - muito - eles - estou - el...     0.000000
# ...                                                 ...          ...
# 4294  espiritismo - humanidade - espirituais - espir...     0.315176
# 4295  falaremos - esprito - escravos - espritos - es...     0.793116
# 4296  esto - como - isso - muito - eles - estou - el...     0.000000
# 4297  esto - como - isso - muito - eles - estou - el...     0.000000
# 4298  esto - como - isso - muito - eles - estou - el...     0.000000
#
#       Representative_document
# 0                       False
# 1                       False
# 2                       False
# 3                       False
# 4                       False
# ...                       ...
# 4294                    False
# 4295                    False
# 4296                    False
# 4297                    False
# 4298                    False
#
# [4299 rows x 8 columns]
