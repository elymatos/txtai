# %%
# !pip install -U spacy
# !pip install spacy-transformers
# Out:
# Looking in indexes: https://pypi.org/simple, https://pypi.ngc.nvidia.com
# Requirement already satisfied: spacy in /home/ematos/miniconda3/envs/gpu-env/lib/python3.11/site-packages (3.7.6)
# Collecting spacy
#   Downloading spacy-3.8.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (27 kB)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.11 in /home/ematos/miniconda3/envs/gpu-env/lib/python3.11/site-packages (from spacy) (3.0.12)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in /home/ematos/miniconda3/envs/gpu-env/lib/python3.11/site-packages (from spacy) (1.0.5)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in /home/ematos/miniconda3/envs/gpu-env/lib/python3.11/site-packages (from spacy) (1.0.10)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in /home/ematos/miniconda3/envs/gpu-env/lib/python3.11/site-packages (from spacy) (2.0.8)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in /home/ematos/miniconda3/envs/gpu-env/lib/python3.11/site-packages (from spacy) (3.0.9)
# Requirement already satisfied: thinc<8.3.0,>=8.2.2 in /home/ematos/miniconda3/envs/gpu-env/lib/python3.11/site-packages (from spacy) (8.2.5)
# Requirement already satisfied: wasabi<1.2.0,>=0.9.1 in /home/ematos/miniconda3/envs/gpu-env/lib/python3.11/site-packages (from spacy) (1.1.3)
# Requirement already satisfied: srsly<3.0.0,>=2.4.3 in /home/ematos/miniconda3/envs/gpu-env/lib/python3.11/site-packages (from spacy) (2.4.8)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in /home/ematos/miniconda3/envs/gpu-env/lib/python3.11/site-packages (from spacy) (2.0.10)
# Requirement already satisfied: weasel<0.5.0,>=0.1.0 in /home/ematos/miniconda3/envs/gpu-env/lib/python3.11/site-packages (from spacy) (0.4.1)
# Requirement already satisfied: typer<1.0.0,>=0.3.0 in /home/ematos/miniconda3/envs/gpu-env/lib/python3.11/site-packages (from spacy) (0.12.5)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in /home/ematos/miniconda3/envs/gpu-env/lib/python3.11/site-packages (from spacy) (4.66.5)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in /home/ematos/miniconda3/envs/gpu-env/lib/python3.11/site-packages (from spacy) (2.32.3)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4 in /home/ematos/miniconda3/envs/gpu-env/lib/python3.11/site-packages (from spacy) (2.9.1)
# Requirement already satisfied: jinja2 in /home/ematos/miniconda3/envs/gpu-env/lib/python3.11/site-packages (from spacy) (3.1.4)
# Requirement already satisfied: setuptools in /home/ematos/miniconda3/envs/gpu-env/lib/python3.11/site-packages (from spacy) (72.1.0)
# Requirement already satisfied: packaging>=20.0 in /home/ematos/miniconda3/envs/gpu-env/lib/python3.11/site-packages (from spacy) (24.1)
# Requirement already satisfied: langcodes<4.0.0,>=3.2.0 in /home/ematos/miniconda3/envs/gpu-env/lib/python3.11/site-packages (from spacy) (3.4.0)
# Requirement already satisfied: numpy>=1.19.0 in /home/ematos/miniconda3/envs/gpu-env/lib/python3.11/site-packages (from spacy) (1.23.5)
# Requirement already satisfied: language-data>=1.2 in /home/ematos/miniconda3/envs/gpu-env/lib/python3.11/site-packages (from langcodes<4.0.0,>=3.2.0->spacy) (1.2.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /home/ematos/miniconda3/envs/gpu-env/lib/python3.11/site-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy) (0.7.0)
# Requirement already satisfied: pydantic-core==2.23.3 in /home/ematos/miniconda3/envs/gpu-env/lib/python3.11/site-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy) (2.23.3)
# Requirement already satisfied: typing-extensions>=4.6.1 in /home/ematos/miniconda3/envs/gpu-env/lib/python3.11/site-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy) (4.11.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /home/ematos/miniconda3/envs/gpu-env/lib/python3.11/site-packages (from requests<3.0.0,>=2.13.0->spacy) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /home/ematos/miniconda3/envs/gpu-env/lib/python3.11/site-packages (from requests<3.0.0,>=2.13.0->spacy) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /home/ematos/miniconda3/envs/gpu-env/lib/python3.11/site-packages (from requests<3.0.0,>=2.13.0->spacy) (2.2.2)
# Requirement already satisfied: certifi>=2017.4.17 in /home/ematos/miniconda3/envs/gpu-env/lib/python3.11/site-packages (from requests<3.0.0,>=2.13.0->spacy) (2024.8.30)
# Requirement already satisfied: blis<0.8.0,>=0.7.8 in /home/ematos/miniconda3/envs/gpu-env/lib/python3.11/site-packages (from thinc<8.3.0,>=8.2.2->spacy) (0.7.11)
# Requirement already satisfied: confection<1.0.0,>=0.0.1 in /home/ematos/miniconda3/envs/gpu-env/lib/python3.11/site-packages (from thinc<8.3.0,>=8.2.2->spacy) (0.1.5)
# Requirement already satisfied: click>=8.0.0 in /home/ematos/miniconda3/envs/gpu-env/lib/python3.11/site-packages (from typer<1.0.0,>=0.3.0->spacy) (8.1.7)
# Requirement already satisfied: shellingham>=1.3.0 in /home/ematos/miniconda3/envs/gpu-env/lib/python3.11/site-packages (from typer<1.0.0,>=0.3.0->spacy) (1.5.4)
# Requirement already satisfied: rich>=10.11.0 in /home/ematos/miniconda3/envs/gpu-env/lib/python3.11/site-packages (from typer<1.0.0,>=0.3.0->spacy) (13.8.1)
# Requirement already satisfied: cloudpathlib<1.0.0,>=0.7.0 in /home/ematos/miniconda3/envs/gpu-env/lib/python3.11/site-packages (from weasel<0.5.0,>=0.1.0->spacy) (0.19.0)
# Requirement already satisfied: smart-open<8.0.0,>=5.2.1 in /home/ematos/miniconda3/envs/gpu-env/lib/python3.11/site-packages (from weasel<0.5.0,>=0.1.0->spacy) (7.0.4)
# Requirement already satisfied: MarkupSafe>=2.0 in /home/ematos/miniconda3/envs/gpu-env/lib/python3.11/site-packages (from jinja2->spacy) (2.1.3)
# Requirement already satisfied: marisa-trie>=0.7.7 in /home/ematos/miniconda3/envs/gpu-env/lib/python3.11/site-packages (from language-data>=1.2->langcodes<4.0.0,>=3.2.0->spacy) (1.2.0)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /home/ematos/miniconda3/envs/gpu-env/lib/python3.11/site-packages (from rich>=10.11.0->typer<1.0.0,>=0.3.0->spacy) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /home/ematos/miniconda3/envs/gpu-env/lib/python3.11/site-packages (from rich>=10.11.0->typer<1.0.0,>=0.3.0->spacy) (2.15.1)
# Requirement already satisfied: wrapt in /home/ematos/miniconda3/envs/gpu-env/lib/python3.11/site-packages (from smart-open<8.0.0,>=5.2.1->weasel<0.5.0,>=0.1.0->spacy) (1.14.1)
# Requirement already satisfied: mdurl~=0.1 in /home/ematos/miniconda3/envs/gpu-env/lib/python3.11/site-packages (from markdown-it-py>=2.2.0->rich>=10.11.0->typer<1.0.0,>=0.3.0->spacy) (0.1.2)
# Downloading spacy-3.8.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (30.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 30.4/30.4 MB 56.2 MB/s eta 0:00:0031m54.1 MB/s eta 0:00:01
# Installing collected packages: spacy
#   Attempting uninstall: spacy
#     Found existing installation: spacy 3.7.6
#     Uninstalling spacy-3.7.6:
#       Successfully uninstalled spacy-3.7.6
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# en-core-web-trf 3.7.3 requires spacy<3.8.0,>=3.7.2, but you have spacy 3.8.0 which is incompatible.
# pt-core-news-md 3.7.0 requires spacy<3.8.0,>=3.7.0, but you have spacy 3.8.0 which is incompatible.
# Successfully installed spacy-3.8.0
# Looking in indexes: https://pypi.org/simple, https://pypi.ngc.nvidia.com
# Requirement already satisfied: spacy-transformers in /home/ematos/miniconda3/envs/gpu-env/lib/python3.11/site-packages (1.3.5)
# Requirement already satisfied: spacy<4.1.0,>=3.5.0 in /home/ematos/miniconda3/envs/gpu-env/lib/python3.11/site-packages (from spacy-transformers) (3.8.0)
# Requirement already satisfied: transformers<4.37.0,>=3.4.0 in /home/ematos/miniconda3/envs/gpu-env/lib/python3.11/site-packages (from spacy-transformers) (4.36.2)
# Requirement already satisfied: torch>=1.8.0 in /home/ematos/miniconda3/envs/gpu-env/lib/python3.11/site-packages (from spacy-transformers) (2.4.1)
# Requirement already satisfied: srsly<3.0.0,>=2.4.0 in /home/ematos/miniconda3/envs/gpu-env/lib/python3.11/site-packages (from spacy-transformers) (2.4.8)
# Requirement already satisfied: spacy-alignments<1.0.0,>=0.7.2 in /home/ematos/miniconda3/envs/gpu-env/lib/python3.11/site-packages (from spacy-transformers) (0.9.1)
# Requirement already satisfied: numpy>=1.19.0 in /home/ematos/miniconda3/envs/gpu-env/lib/python3.11/site-packages (from spacy-transformers) (1.23.5)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.11 in /home/ematos/miniconda3/envs/gpu-env/lib/python3.11/site-packages (from spacy<4.1.0,>=3.5.0->spacy-transformers) (3.0.12)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in /home/ematos/miniconda3/envs/gpu-env/lib/python3.11/site-packages (from spacy<4.1.0,>=3.5.0->spacy-transformers) (1.0.5)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in /home/ematos/miniconda3/envs/gpu-env/lib/python3.11/site-packages (from spacy<4.1.0,>=3.5.0->spacy-transformers) (1.0.10)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in /home/ematos/miniconda3/envs/gpu-env/lib/python3.11/site-packages (from spacy<4.1.0,>=3.5.0->spacy-transformers) (2.0.8)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in /home/ematos/miniconda3/envs/gpu-env/lib/python3.11/site-packages (from spacy<4.1.0,>=3.5.0->spacy-transformers) (3.0.9)
# Requirement already satisfied: thinc<8.3.0,>=8.2.2 in /home/ematos/miniconda3/envs/gpu-env/lib/python3.11/site-packages (from spacy<4.1.0,>=3.5.0->spacy-transformers) (8.2.5)
# Requirement already satisfied: wasabi<1.2.0,>=0.9.1 in /home/ematos/miniconda3/envs/gpu-env/lib/python3.11/site-packages (from spacy<4.1.0,>=3.5.0->spacy-transformers) (1.1.3)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in /home/ematos/miniconda3/envs/gpu-env/lib/python3.11/site-packages (from spacy<4.1.0,>=3.5.0->spacy-transformers) (2.0.10)
# Requirement already satisfied: weasel<0.5.0,>=0.1.0 in /home/ematos/miniconda3/envs/gpu-env/lib/python3.11/site-packages (from spacy<4.1.0,>=3.5.0->spacy-transformers) (0.4.1)
# Requirement already satisfied: typer<1.0.0,>=0.3.0 in /home/ematos/miniconda3/envs/gpu-env/lib/python3.11/site-packages (from spacy<4.1.0,>=3.5.0->spacy-transformers) (0.12.5)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in /home/ematos/miniconda3/envs/gpu-env/lib/python3.11/site-packages (from spacy<4.1.0,>=3.5.0->spacy-transformers) (4.66.5)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in /home/ematos/miniconda3/envs/gpu-env/lib/python3.11/site-packages (from spacy<4.1.0,>=3.5.0->spacy-transformers) (2.32.3)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4 in /home/ematos/miniconda3/envs/gpu-env/lib/python3.11/site-packages (from spacy<4.1.0,>=3.5.0->spacy-transformers) (2.9.1)
# Requirement already satisfied: jinja2 in /home/ematos/miniconda3/envs/gpu-env/lib/python3.11/site-packages (from spacy<4.1.0,>=3.5.0->spacy-transformers) (3.1.4)
# Requirement already satisfied: setuptools in /home/ematos/miniconda3/envs/gpu-env/lib/python3.11/site-packages (from spacy<4.1.0,>=3.5.0->spacy-transformers) (72.1.0)
# Requirement already satisfied: packaging>=20.0 in /home/ematos/miniconda3/envs/gpu-env/lib/python3.11/site-packages (from spacy<4.1.0,>=3.5.0->spacy-transformers) (24.1)
# Requirement already satisfied: langcodes<4.0.0,>=3.2.0 in /home/ematos/miniconda3/envs/gpu-env/lib/python3.11/site-packages (from spacy<4.1.0,>=3.5.0->spacy-transformers) (3.4.0)
# Requirement already satisfied: filelock in /home/ematos/miniconda3/envs/gpu-env/lib/python3.11/site-packages (from torch>=1.8.0->spacy-transformers) (3.16.0)
# Requirement already satisfied: typing-extensions>=4.8.0 in /home/ematos/miniconda3/envs/gpu-env/lib/python3.11/site-packages (from torch>=1.8.0->spacy-transformers) (4.11.0)
# Requirement already satisfied: sympy in /home/ematos/miniconda3/envs/gpu-env/lib/python3.11/site-packages (from torch>=1.8.0->spacy-transformers) (1.13.2)
# Requirement already satisfied: networkx in /home/ematos/miniconda3/envs/gpu-env/lib/python3.11/site-packages (from torch>=1.8.0->spacy-transformers) (3.3)
# Requirement already satisfied: fsspec in /home/ematos/miniconda3/envs/gpu-env/lib/python3.11/site-packages (from torch>=1.8.0->spacy-transformers) (2024.6.1)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.1.105 in /home/ematos/miniconda3/envs/gpu-env/lib/python3.11/site-packages (from torch>=1.8.0->spacy-transformers) (12.1.105)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.1.105 in /home/ematos/miniconda3/envs/gpu-env/lib/python3.11/site-packages (from torch>=1.8.0->spacy-transformers) (12.1.105)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.1.105 in /home/ematos/miniconda3/envs/gpu-env/lib/python3.11/site-packages (from torch>=1.8.0->spacy-transformers) (12.1.105)
# Requirement already satisfied: nvidia-cudnn-cu12==9.1.0.70 in /home/ematos/miniconda3/envs/gpu-env/lib/python3.11/site-packages (from torch>=1.8.0->spacy-transformers) (9.1.0.70)
# Requirement already satisfied: nvidia-cublas-cu12==12.1.3.1 in /home/ematos/miniconda3/envs/gpu-env/lib/python3.11/site-packages (from torch>=1.8.0->spacy-transformers) (12.1.3.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.0.2.54 in /home/ematos/miniconda3/envs/gpu-env/lib/python3.11/site-packages (from torch>=1.8.0->spacy-transformers) (11.0.2.54)
# Requirement already satisfied: nvidia-curand-cu12==10.3.2.106 in /home/ematos/miniconda3/envs/gpu-env/lib/python3.11/site-packages (from torch>=1.8.0->spacy-transformers) (10.3.2.106)
# Requirement already satisfied: nvidia-cusolver-cu12==11.4.5.107 in /home/ematos/miniconda3/envs/gpu-env/lib/python3.11/site-packages (from torch>=1.8.0->spacy-transformers) (11.4.5.107)
# Requirement already satisfied: nvidia-cusparse-cu12==12.1.0.106 in /home/ematos/miniconda3/envs/gpu-env/lib/python3.11/site-packages (from torch>=1.8.0->spacy-transformers) (12.1.0.106)
# Requirement already satisfied: nvidia-nccl-cu12==2.20.5 in /home/ematos/miniconda3/envs/gpu-env/lib/python3.11/site-packages (from torch>=1.8.0->spacy-transformers) (2.20.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.1.105 in /home/ematos/miniconda3/envs/gpu-env/lib/python3.11/site-packages (from torch>=1.8.0->spacy-transformers) (12.1.105)
# Requirement already satisfied: triton==3.0.0 in /home/ematos/miniconda3/envs/gpu-env/lib/python3.11/site-packages (from torch>=1.8.0->spacy-transformers) (3.0.0)
# Requirement already satisfied: nvidia-nvjitlink-cu12 in /home/ematos/miniconda3/envs/gpu-env/lib/python3.11/site-packages (from nvidia-cusolver-cu12==11.4.5.107->torch>=1.8.0->spacy-transformers) (12.6.68)
# Requirement already satisfied: huggingface-hub<1.0,>=0.19.3 in /home/ematos/miniconda3/envs/gpu-env/lib/python3.11/site-packages (from transformers<4.37.0,>=3.4.0->spacy-transformers) (0.24.6)
# Requirement already satisfied: pyyaml>=5.1 in /home/ematos/miniconda3/envs/gpu-env/lib/python3.11/site-packages (from transformers<4.37.0,>=3.4.0->spacy-transformers) (6.0.1)
# Requirement already satisfied: regex!=2019.12.17 in /home/ematos/miniconda3/envs/gpu-env/lib/python3.11/site-packages (from transformers<4.37.0,>=3.4.0->spacy-transformers) (2024.7.24)
# Requirement already satisfied: tokenizers<0.19,>=0.14 in /home/ematos/miniconda3/envs/gpu-env/lib/python3.11/site-packages (from transformers<4.37.0,>=3.4.0->spacy-transformers) (0.15.2)
# Requirement already satisfied: safetensors>=0.3.1 in /home/ematos/miniconda3/envs/gpu-env/lib/python3.11/site-packages (from transformers<4.37.0,>=3.4.0->spacy-transformers) (0.4.5)
# Requirement already satisfied: language-data>=1.2 in /home/ematos/miniconda3/envs/gpu-env/lib/python3.11/site-packages (from langcodes<4.0.0,>=3.2.0->spacy<4.1.0,>=3.5.0->spacy-transformers) (1.2.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /home/ematos/miniconda3/envs/gpu-env/lib/python3.11/site-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy<4.1.0,>=3.5.0->spacy-transformers) (0.7.0)
# Requirement already satisfied: pydantic-core==2.23.3 in /home/ematos/miniconda3/envs/gpu-env/lib/python3.11/site-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy<4.1.0,>=3.5.0->spacy-transformers) (2.23.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in /home/ematos/miniconda3/envs/gpu-env/lib/python3.11/site-packages (from requests<3.0.0,>=2.13.0->spacy<4.1.0,>=3.5.0->spacy-transformers) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /home/ematos/miniconda3/envs/gpu-env/lib/python3.11/site-packages (from requests<3.0.0,>=2.13.0->spacy<4.1.0,>=3.5.0->spacy-transformers) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /home/ematos/miniconda3/envs/gpu-env/lib/python3.11/site-packages (from requests<3.0.0,>=2.13.0->spacy<4.1.0,>=3.5.0->spacy-transformers) (2.2.2)
# Requirement already satisfied: certifi>=2017.4.17 in /home/ematos/miniconda3/envs/gpu-env/lib/python3.11/site-packages (from requests<3.0.0,>=2.13.0->spacy<4.1.0,>=3.5.0->spacy-transformers) (2024.8.30)
# Requirement already satisfied: blis<0.8.0,>=0.7.8 in /home/ematos/miniconda3/envs/gpu-env/lib/python3.11/site-packages (from thinc<8.3.0,>=8.2.2->spacy<4.1.0,>=3.5.0->spacy-transformers) (0.7.11)
# Requirement already satisfied: confection<1.0.0,>=0.0.1 in /home/ematos/miniconda3/envs/gpu-env/lib/python3.11/site-packages (from thinc<8.3.0,>=8.2.2->spacy<4.1.0,>=3.5.0->spacy-transformers) (0.1.5)
# Requirement already satisfied: click>=8.0.0 in /home/ematos/miniconda3/envs/gpu-env/lib/python3.11/site-packages (from typer<1.0.0,>=0.3.0->spacy<4.1.0,>=3.5.0->spacy-transformers) (8.1.7)
# Requirement already satisfied: shellingham>=1.3.0 in /home/ematos/miniconda3/envs/gpu-env/lib/python3.11/site-packages (from typer<1.0.0,>=0.3.0->spacy<4.1.0,>=3.5.0->spacy-transformers) (1.5.4)
# Requirement already satisfied: rich>=10.11.0 in /home/ematos/miniconda3/envs/gpu-env/lib/python3.11/site-packages (from typer<1.0.0,>=0.3.0->spacy<4.1.0,>=3.5.0->spacy-transformers) (13.8.1)
# Requirement already satisfied: cloudpathlib<1.0.0,>=0.7.0 in /home/ematos/miniconda3/envs/gpu-env/lib/python3.11/site-packages (from weasel<0.5.0,>=0.1.0->spacy<4.1.0,>=3.5.0->spacy-transformers) (0.19.0)
# Requirement already satisfied: smart-open<8.0.0,>=5.2.1 in /home/ematos/miniconda3/envs/gpu-env/lib/python3.11/site-packages (from weasel<0.5.0,>=0.1.0->spacy<4.1.0,>=3.5.0->spacy-transformers) (7.0.4)
# Requirement already satisfied: MarkupSafe>=2.0 in /home/ematos/miniconda3/envs/gpu-env/lib/python3.11/site-packages (from jinja2->spacy<4.1.0,>=3.5.0->spacy-transformers) (2.1.3)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /home/ematos/miniconda3/envs/gpu-env/lib/python3.11/site-packages (from sympy->torch>=1.8.0->spacy-transformers) (1.3.0)
# Requirement already satisfied: marisa-trie>=0.7.7 in /home/ematos/miniconda3/envs/gpu-env/lib/python3.11/site-packages (from language-data>=1.2->langcodes<4.0.0,>=3.2.0->spacy<4.1.0,>=3.5.0->spacy-transformers) (1.2.0)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /home/ematos/miniconda3/envs/gpu-env/lib/python3.11/site-packages (from rich>=10.11.0->typer<1.0.0,>=0.3.0->spacy<4.1.0,>=3.5.0->spacy-transformers) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /home/ematos/miniconda3/envs/gpu-env/lib/python3.11/site-packages (from rich>=10.11.0->typer<1.0.0,>=0.3.0->spacy<4.1.0,>=3.5.0->spacy-transformers) (2.15.1)
# Requirement already satisfied: wrapt in /home/ematos/miniconda3/envs/gpu-env/lib/python3.11/site-packages (from smart-open<8.0.0,>=5.2.1->weasel<0.5.0,>=0.1.0->spacy<4.1.0,>=3.5.0->spacy-transformers) (1.14.1)
# Requirement already satisfied: mdurl~=0.1 in /home/ematos/miniconda3/envs/gpu-env/lib/python3.11/site-packages (from markdown-it-py>=2.2.0->rich>=10.11.0->typer<1.0.0,>=0.3.0->spacy<4.1.0,>=3.5.0->spacy-transformers) (0.1.2)

# %%
import spacy
import spacy_transformers
from spacy import displacy
from collections import Counter
import pandas as pd
pd.options.display.max_rows = 600
pd.options.display.max_colwidth = 400
# Out:
# /home/ematos/miniconda3/envs/gpu-env/lib/python3.11/site-packages/transformers/utils/generic.py:441: FutureWarning: `torch.utils._pytree._register_pytree_node` is deprecated. Please use `torch.utils._pytree.register_pytree_node` instead.
#   _torch_pytree._register_pytree_node(
# /home/ematos/miniconda3/envs/gpu-env/lib/python3.11/site-packages/transformers/utils/generic.py:309: FutureWarning: `torch.utils._pytree._register_pytree_node` is deprecated. Please use `torch.utils._pytree.register_pytree_node` instead.
#   _torch_pytree._register_pytree_node(

# %%
# !python -m spacy download en_core_web_trf
# Out:
# /home/ematos/miniconda3/envs/gpu-env/lib/python3.11/site-packages/transformers/utils/generic.py:441: FutureWarning: `torch.utils._pytree._register_pytree_node` is deprecated. Please use `torch.utils._pytree.register_pytree_node` instead.
#   _torch_pytree._register_pytree_node(
# Looking in indexes: https://pypi.org/simple, https://pypi.ngc.nvidia.com
# Collecting en-core-web-trf==3.7.3
#   Downloading https://github.com/explosion/spacy-models/releases/download/en_core_web_trf-3.7.3/en_core_web_trf-3.7.3-py3-none-any.whl (457.4 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 457.4/457.4 MB 75.1 MB/s eta 0:00:000:00:010:00:01:01
# Collecting spacy<3.8.0,>=3.7.2 (from en-core-web-trf==3.7.3)
#   Downloading spacy-3.7.6-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (27 kB)
# Requirement already satisfied: spacy-curated-transformers<0.3.0,>=0.2.0 in /home/ematos/miniconda3/envs/gpu-env/lib/python3.11/site-packages (from en-core-web-trf==3.7.3) (0.2.2)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.11 in /home/ematos/miniconda3/envs/gpu-env/lib/python3.11/site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-trf==3.7.3) (3.0.12)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in /home/ematos/miniconda3/envs/gpu-env/lib/python3.11/site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-trf==3.7.3) (1.0.5)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in /home/ematos/miniconda3/envs/gpu-env/lib/python3.11/site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-trf==3.7.3) (1.0.10)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in /home/ematos/miniconda3/envs/gpu-env/lib/python3.11/site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-trf==3.7.3) (2.0.8)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in /home/ematos/miniconda3/envs/gpu-env/lib/python3.11/site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-trf==3.7.3) (3.0.9)
# Requirement already satisfied: thinc<8.3.0,>=8.2.2 in /home/ematos/miniconda3/envs/gpu-env/lib/python3.11/site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-trf==3.7.3) (8.2.5)
# Requirement already satisfied: wasabi<1.2.0,>=0.9.1 in /home/ematos/miniconda3/envs/gpu-env/lib/python3.11/site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-trf==3.7.3) (1.1.3)
# Requirement already satisfied: srsly<3.0.0,>=2.4.3 in /home/ematos/miniconda3/envs/gpu-env/lib/python3.11/site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-trf==3.7.3) (2.4.8)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in /home/ematos/miniconda3/envs/gpu-env/lib/python3.11/site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-trf==3.7.3) (2.0.10)
# Requirement already satisfied: weasel<0.5.0,>=0.1.0 in /home/ematos/miniconda3/envs/gpu-env/lib/python3.11/site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-trf==3.7.3) (0.4.1)
# Requirement already satisfied: typer<1.0.0,>=0.3.0 in /home/ematos/miniconda3/envs/gpu-env/lib/python3.11/site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-trf==3.7.3) (0.12.5)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in /home/ematos/miniconda3/envs/gpu-env/lib/python3.11/site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-trf==3.7.3) (4.66.5)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in /home/ematos/miniconda3/envs/gpu-env/lib/python3.11/site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-trf==3.7.3) (2.32.3)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4 in /home/ematos/miniconda3/envs/gpu-env/lib/python3.11/site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-trf==3.7.3) (2.9.1)
# Requirement already satisfied: jinja2 in /home/ematos/miniconda3/envs/gpu-env/lib/python3.11/site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-trf==3.7.3) (3.1.4)
# Requirement already satisfied: setuptools in /home/ematos/miniconda3/envs/gpu-env/lib/python3.11/site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-trf==3.7.3) (72.1.0)
# Requirement already satisfied: packaging>=20.0 in /home/ematos/miniconda3/envs/gpu-env/lib/python3.11/site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-trf==3.7.3) (24.1)
# Requirement already satisfied: langcodes<4.0.0,>=3.2.0 in /home/ematos/miniconda3/envs/gpu-env/lib/python3.11/site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-trf==3.7.3) (3.4.0)
# Requirement already satisfied: numpy>=1.19.0 in /home/ematos/miniconda3/envs/gpu-env/lib/python3.11/site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-trf==3.7.3) (1.23.5)
# Requirement already satisfied: curated-transformers<0.2.0,>=0.1.0 in /home/ematos/miniconda3/envs/gpu-env/lib/python3.11/site-packages (from spacy-curated-transformers<0.3.0,>=0.2.0->en-core-web-trf==3.7.3) (0.1.1)
# Requirement already satisfied: curated-tokenizers<0.1.0,>=0.0.9 in /home/ematos/miniconda3/envs/gpu-env/lib/python3.11/site-packages (from spacy-curated-transformers<0.3.0,>=0.2.0->en-core-web-trf==3.7.3) (0.0.9)
# Requirement already satisfied: torch>=1.12.0 in /home/ematos/miniconda3/envs/gpu-env/lib/python3.11/site-packages (from spacy-curated-transformers<0.3.0,>=0.2.0->en-core-web-trf==3.7.3) (2.4.1)
# Requirement already satisfied: regex>=2022 in /home/ematos/miniconda3/envs/gpu-env/lib/python3.11/site-packages (from curated-tokenizers<0.1.0,>=0.0.9->spacy-curated-transformers<0.3.0,>=0.2.0->en-core-web-trf==3.7.3) (2024.7.24)
# Requirement already satisfied: language-data>=1.2 in /home/ematos/miniconda3/envs/gpu-env/lib/python3.11/site-packages (from langcodes<4.0.0,>=3.2.0->spacy<3.8.0,>=3.7.2->en-core-web-trf==3.7.3) (1.2.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /home/ematos/miniconda3/envs/gpu-env/lib/python3.11/site-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy<3.8.0,>=3.7.2->en-core-web-trf==3.7.3) (0.7.0)
# Requirement already satisfied: pydantic-core==2.23.3 in /home/ematos/miniconda3/envs/gpu-env/lib/python3.11/site-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy<3.8.0,>=3.7.2->en-core-web-trf==3.7.3) (2.23.3)
# Requirement already satisfied: typing-extensions>=4.6.1 in /home/ematos/miniconda3/envs/gpu-env/lib/python3.11/site-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy<3.8.0,>=3.7.2->en-core-web-trf==3.7.3) (4.11.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /home/ematos/miniconda3/envs/gpu-env/lib/python3.11/site-packages (from requests<3.0.0,>=2.13.0->spacy<3.8.0,>=3.7.2->en-core-web-trf==3.7.3) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /home/ematos/miniconda3/envs/gpu-env/lib/python3.11/site-packages (from requests<3.0.0,>=2.13.0->spacy<3.8.0,>=3.7.2->en-core-web-trf==3.7.3) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /home/ematos/miniconda3/envs/gpu-env/lib/python3.11/site-packages (from requests<3.0.0,>=2.13.0->spacy<3.8.0,>=3.7.2->en-core-web-trf==3.7.3) (2.2.2)
# Requirement already satisfied: certifi>=2017.4.17 in /home/ematos/miniconda3/envs/gpu-env/lib/python3.11/site-packages (from requests<3.0.0,>=2.13.0->spacy<3.8.0,>=3.7.2->en-core-web-trf==3.7.3) (2024.8.30)
# Requirement already satisfied: blis<0.8.0,>=0.7.8 in /home/ematos/miniconda3/envs/gpu-env/lib/python3.11/site-packages (from thinc<8.3.0,>=8.2.2->spacy<3.8.0,>=3.7.2->en-core-web-trf==3.7.3) (0.7.11)
# Requirement already satisfied: confection<1.0.0,>=0.0.1 in /home/ematos/miniconda3/envs/gpu-env/lib/python3.11/site-packages (from thinc<8.3.0,>=8.2.2->spacy<3.8.0,>=3.7.2->en-core-web-trf==3.7.3) (0.1.5)
# Requirement already satisfied: filelock in /home/ematos/miniconda3/envs/gpu-env/lib/python3.11/site-packages (from torch>=1.12.0->spacy-curated-transformers<0.3.0,>=0.2.0->en-core-web-trf==3.7.3) (3.16.0)
# Requirement already satisfied: sympy in /home/ematos/miniconda3/envs/gpu-env/lib/python3.11/site-packages (from torch>=1.12.0->spacy-curated-transformers<0.3.0,>=0.2.0->en-core-web-trf==3.7.3) (1.13.2)
# Requirement already satisfied: networkx in /home/ematos/miniconda3/envs/gpu-env/lib/python3.11/site-packages (from torch>=1.12.0->spacy-curated-transformers<0.3.0,>=0.2.0->en-core-web-trf==3.7.3) (3.3)
# Requirement already satisfied: fsspec in /home/ematos/miniconda3/envs/gpu-env/lib/python3.11/site-packages (from torch>=1.12.0->spacy-curated-transformers<0.3.0,>=0.2.0->en-core-web-trf==3.7.3) (2024.6.1)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.1.105 in /home/ematos/miniconda3/envs/gpu-env/lib/python3.11/site-packages (from torch>=1.12.0->spacy-curated-transformers<0.3.0,>=0.2.0->en-core-web-trf==3.7.3) (12.1.105)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.1.105 in /home/ematos/miniconda3/envs/gpu-env/lib/python3.11/site-packages (from torch>=1.12.0->spacy-curated-transformers<0.3.0,>=0.2.0->en-core-web-trf==3.7.3) (12.1.105)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.1.105 in /home/ematos/miniconda3/envs/gpu-env/lib/python3.11/site-packages (from torch>=1.12.0->spacy-curated-transformers<0.3.0,>=0.2.0->en-core-web-trf==3.7.3) (12.1.105)
# Requirement already satisfied: nvidia-cudnn-cu12==9.1.0.70 in /home/ematos/miniconda3/envs/gpu-env/lib/python3.11/site-packages (from torch>=1.12.0->spacy-curated-transformers<0.3.0,>=0.2.0->en-core-web-trf==3.7.3) (9.1.0.70)
# Requirement already satisfied: nvidia-cublas-cu12==12.1.3.1 in /home/ematos/miniconda3/envs/gpu-env/lib/python3.11/site-packages (from torch>=1.12.0->spacy-curated-transformers<0.3.0,>=0.2.0->en-core-web-trf==3.7.3) (12.1.3.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.0.2.54 in /home/ematos/miniconda3/envs/gpu-env/lib/python3.11/site-packages (from torch>=1.12.0->spacy-curated-transformers<0.3.0,>=0.2.0->en-core-web-trf==3.7.3) (11.0.2.54)
# Requirement already satisfied: nvidia-curand-cu12==10.3.2.106 in /home/ematos/miniconda3/envs/gpu-env/lib/python3.11/site-packages (from torch>=1.12.0->spacy-curated-transformers<0.3.0,>=0.2.0->en-core-web-trf==3.7.3) (10.3.2.106)
# Requirement already satisfied: nvidia-cusolver-cu12==11.4.5.107 in /home/ematos/miniconda3/envs/gpu-env/lib/python3.11/site-packages (from torch>=1.12.0->spacy-curated-transformers<0.3.0,>=0.2.0->en-core-web-trf==3.7.3) (11.4.5.107)
# Requirement already satisfied: nvidia-cusparse-cu12==12.1.0.106 in /home/ematos/miniconda3/envs/gpu-env/lib/python3.11/site-packages (from torch>=1.12.0->spacy-curated-transformers<0.3.0,>=0.2.0->en-core-web-trf==3.7.3) (12.1.0.106)
# Requirement already satisfied: nvidia-nccl-cu12==2.20.5 in /home/ematos/miniconda3/envs/gpu-env/lib/python3.11/site-packages (from torch>=1.12.0->spacy-curated-transformers<0.3.0,>=0.2.0->en-core-web-trf==3.7.3) (2.20.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.1.105 in /home/ematos/miniconda3/envs/gpu-env/lib/python3.11/site-packages (from torch>=1.12.0->spacy-curated-transformers<0.3.0,>=0.2.0->en-core-web-trf==3.7.3) (12.1.105)
# Requirement already satisfied: triton==3.0.0 in /home/ematos/miniconda3/envs/gpu-env/lib/python3.11/site-packages (from torch>=1.12.0->spacy-curated-transformers<0.3.0,>=0.2.0->en-core-web-trf==3.7.3) (3.0.0)
# Requirement already satisfied: nvidia-nvjitlink-cu12 in /home/ematos/miniconda3/envs/gpu-env/lib/python3.11/site-packages (from nvidia-cusolver-cu12==11.4.5.107->torch>=1.12.0->spacy-curated-transformers<0.3.0,>=0.2.0->en-core-web-trf==3.7.3) (12.6.68)
# Requirement already satisfied: click>=8.0.0 in /home/ematos/miniconda3/envs/gpu-env/lib/python3.11/site-packages (from typer<1.0.0,>=0.3.0->spacy<3.8.0,>=3.7.2->en-core-web-trf==3.7.3) (8.1.7)
# Requirement already satisfied: shellingham>=1.3.0 in /home/ematos/miniconda3/envs/gpu-env/lib/python3.11/site-packages (from typer<1.0.0,>=0.3.0->spacy<3.8.0,>=3.7.2->en-core-web-trf==3.7.3) (1.5.4)
# Requirement already satisfied: rich>=10.11.0 in /home/ematos/miniconda3/envs/gpu-env/lib/python3.11/site-packages (from typer<1.0.0,>=0.3.0->spacy<3.8.0,>=3.7.2->en-core-web-trf==3.7.3) (13.8.1)
# Requirement already satisfied: cloudpathlib<1.0.0,>=0.7.0 in /home/ematos/miniconda3/envs/gpu-env/lib/python3.11/site-packages (from weasel<0.5.0,>=0.1.0->spacy<3.8.0,>=3.7.2->en-core-web-trf==3.7.3) (0.19.0)
# Requirement already satisfied: smart-open<8.0.0,>=5.2.1 in /home/ematos/miniconda3/envs/gpu-env/lib/python3.11/site-packages (from weasel<0.5.0,>=0.1.0->spacy<3.8.0,>=3.7.2->en-core-web-trf==3.7.3) (7.0.4)
# Requirement already satisfied: MarkupSafe>=2.0 in /home/ematos/miniconda3/envs/gpu-env/lib/python3.11/site-packages (from jinja2->spacy<3.8.0,>=3.7.2->en-core-web-trf==3.7.3) (2.1.3)
# Requirement already satisfied: marisa-trie>=0.7.7 in /home/ematos/miniconda3/envs/gpu-env/lib/python3.11/site-packages (from language-data>=1.2->langcodes<4.0.0,>=3.2.0->spacy<3.8.0,>=3.7.2->en-core-web-trf==3.7.3) (1.2.0)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /home/ematos/miniconda3/envs/gpu-env/lib/python3.11/site-packages (from rich>=10.11.0->typer<1.0.0,>=0.3.0->spacy<3.8.0,>=3.7.2->en-core-web-trf==3.7.3) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /home/ematos/miniconda3/envs/gpu-env/lib/python3.11/site-packages (from rich>=10.11.0->typer<1.0.0,>=0.3.0->spacy<3.8.0,>=3.7.2->en-core-web-trf==3.7.3) (2.15.1)
# Requirement already satisfied: wrapt in /home/ematos/miniconda3/envs/gpu-env/lib/python3.11/site-packages (from smart-open<8.0.0,>=5.2.1->weasel<0.5.0,>=0.1.0->spacy<3.8.0,>=3.7.2->en-core-web-trf==3.7.3) (1.14.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /home/ematos/miniconda3/envs/gpu-env/lib/python3.11/site-packages (from sympy->torch>=1.12.0->spacy-curated-transformers<0.3.0,>=0.2.0->en-core-web-trf==3.7.3) (1.3.0)
# Requirement already satisfied: mdurl~=0.1 in /home/ematos/miniconda3/envs/gpu-env/lib/python3.11/site-packages (from markdown-it-py>=2.2.0->rich>=10.11.0->typer<1.0.0,>=0.3.0->spacy<3.8.0,>=3.7.2->en-core-web-trf==3.7.3) (0.1.2)
# Downloading spacy-3.7.6-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (30.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 30.5/30.5 MB 61.5 MB/s eta 0:00:00m eta 0:00:010:00:01
# Installing collected packages: spacy
#   Attempting uninstall: spacy
#     Found existing installation: spacy 3.8.0
#     Uninstalling spacy-3.8.0:
#       Successfully uninstalled spacy-3.8.0
# Successfully installed spacy-3.7.6
# ✔ Download and installation successful
# You can now load the package via spacy.load('en_core_web_trf')

# %%
# make the factory work
#from rel_pipe import make_relation_extractor, score_relations

# make the config work
#from rel_model import create_relation_model, create_classification_layer, create_instances

import en_core_web_trf
nlp = en_core_web_trf.load()
# Out:
# /home/ematos/miniconda3/envs/gpu-env/lib/python3.11/site-packages/spacy/util.py:910: UserWarning: [W095] Model 'en_core_web_trf' (3.7.3) was trained with spaCy v3.7.2 and may not be 100% compatible with the current version (3.8.0). If you see errors or degraded performance, download a newer compatible model or retrain your custom model with the current spaCy version. For more details and available updates, run: python -m spacy validate
#   warnings.warn(warn_msg)
# /home/ematos/miniconda3/envs/gpu-env/lib/python3.11/site-packages/thinc/shims/pytorch.py:253: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   model.load_state_dict(torch.load(filelike, map_location=device))

# %%
filepath = '../files/texto01_en.txt'
text = open(filepath, encoding='utf-8').read()
document = nlp(text)
# Out:
# /home/ematos/miniconda3/envs/gpu-env/lib/python3.11/site-packages/thinc/shims/pytorch.py:114: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(self._mixed_precision):

# %%
document.ents
# Out:
# (Rivail,
#  the Château-du-Loir,
#  PARIS,
#  September 26, 1846,
#  CHÂTEAU DU LOIR,
#  September 27, 1846,
#  the day before yesterday,
#  yesterday,
#  Amélie,
#  The school year,
#  Tuesday,
#  the
#  first day,
#  60,
#  last year,
#  only 40,
#  the following days,
#  next Monday,
#  the first day,
#  Crispoul,
#  Grandins,
#  Lerouxs,
#  first,
#  this year,
#  Lesquillers,
#  one,
#  night,
#  five,
#  night,
#  Ferran,
#  Ballet,
#  Monday,
#  Morin,
#  only 15 years old,
#  Vorler,
#  yesterday, Thursday,
#  today,
#  two,
#  Wednesday,
#  morning,
#  8:30,
#  Éloïse,
#  Aix,
#  Éloïse,
#  Éloïse,
#  Lévi,
#  Saturdays,
#  9 a.m.,
#  only 5 francs,
#  November 1st,
#  Amélie,
#  tomorrow, Saturday)

# %%
for named_entity in document.ents:
    print(named_entity, named_entity.label_)
# Out:
# Rivail PERSON
# the Château-du-Loir FAC
# PARIS GPE
# September 26, 1846 DATE
# CHÂTEAU DU LOIR GPE
# September 27, 1846 DATE
# the day before yesterday DATE
# yesterday DATE
# Amélie PERSON
# The school year DATE
# Tuesday DATE
# the
# first day DATE
# 60 CARDINAL
# last year DATE
# only 40 CARDINAL
# the following days DATE
# next Monday DATE
# the first day DATE
# Crispoul PERSON
# Grandins PERSON
# Lerouxs PERSON
# first ORDINAL
# this year DATE
# Lesquillers PERSON
# one CARDINAL
# night TIME
# five CARDINAL
# night TIME
# Ferran PERSON
# Ballet PERSON
# Monday DATE
# Morin PERSON
# only 15 years old DATE
# Vorler PERSON
# yesterday, Thursday DATE
# today DATE
# two CARDINAL
# Wednesday DATE
# morning TIME
# 8:30 TIME
# Éloïse PERSON
# Aix GPE
# Éloïse PERSON
# Éloïse PERSON
# Lévi PERSON
# Saturdays DATE
# 9 a.m. TIME
# only 5 francs MONEY
# November 1st DATE
# Amélie PERSON
# tomorrow, Saturday DATE

# %%
import math
number_of_chunks = 80

chunk_size = math.ceil(len(text) / number_of_chunks)

text_chunks = []

for number in range(0, len(text), chunk_size):
    text_chunk = text[number:number+chunk_size]
    text_chunks.append(text_chunk)

# %%
chunked_documents = list(nlp.pipe(text_chunks))

# %%
people = []

for document in chunked_documents:
    for named_entity in document.ents:
        if named_entity.label_ == "PER":
            people.append(named_entity.text)

people_tally = Counter(people)

df = pd.DataFrame(people_tally.most_common(), columns=['character', 'count'])
df
