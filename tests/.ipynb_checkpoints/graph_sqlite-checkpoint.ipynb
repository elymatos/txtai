# %%
import os
import sqlite3

from txtai.embeddings import Embeddings

# Create embeddings instance with a semantic graph
embeddings = Embeddings({
  "path": "sentence-transformers/all-MiniLM-L6-v2",
  "content": True,
  "functions": [
    {"name": "graph", "function": "graph.attribute"},
  ],
  "expressions": [
      {"name": "category", "expression": "graph(indexid, 'category')"},
      {"name": "topic", "expression": "graph(indexid, 'topic')"},
      {"name": "topicrank", "expression": "graph(indexid, 'topicrank')"}
  ],
  "graph": {
      "limit": 15,
      "minscore": 0.1,
      "topics": {
          "categories": ["Rascunho de carta",
                            "Carta",
                            "Nota",
                            "Cópia de carta",
                            "Prece",
                            "Evocação",
                            "Fragmento",
                            "Psicografia",
                            "Imagem",
                            "Discurso",
                            "Escritura",
                            "Comunicação",
                            "Diálogo",
                            "Prova de página",
                            "Inventário",
                            "Dissertação",
                            "Impresso",
                            "Anotação",
                            "Bilhete",
                            "Caderno de cartas"]
      }
  }
})

# Connection to database file
db_dir = os.path.abspath("/home/ematos/devel/kardec/kardec_laravel/database")
database_file = os.path.join(db_dir, "dataset.txtai.sqlite3")

db = sqlite3.connect(database_file)
cur = db.cursor()

# Select tagged sentences without a NLP label. NLP labels are set for non-informative sentences.
cur.execute("SELECT idSentence as id, sentence as text from sentence")

#for row in cur:
  # Unpack row
#  uid, text = row
#  print(uid)
#  print(text)
#  embeddings.index(uid, text)
embeddings.index(cur)
# Free database resources
db.close()

# Store reference to graph
graph = embeddings.graph
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[16], line 62
#      54 cur.execute("SELECT sentence from sentence")
#      56 #for row in cur:
#      57   # Unpack row
#      58 #  uid, text = row
#      59 #  print(uid)
#      60 #  print(text)
#      61 #  embeddings.index(uid, text)
# ---> 62 embeddings.index(cur)
#      63 # Free database resources
#      64 db.close()
#
# File ~/miniconda3/envs/txtai-env/lib/python3.12/site-packages/txtai/embeddings/base.py:118, in Embeddings.index(self, documents, reindex)
#     114 stream = Stream(self, Action.REINDEX if reindex else Action.INDEX)
#     116 with tempfile.NamedTemporaryFile(mode="wb", suffix=".npy") as buffer:
#     117     # Load documents into database and transform to vectors
# --> 118     ids, dimensions, embeddings = transform(stream(documents), buffer)
#     119     if embeddings is not None:
#     120         # Build LSA model (if enabled). Remove principal components from embeddings.
#     121         if self.config.get("pca"):
#
# File ~/miniconda3/envs/txtai-env/lib/python3.12/site-packages/txtai/embeddings/index/transform.py:75, in Transform.__call__(self, documents, buffer)
#      72 ids, dimensions, embeddings = None, None, None
#      74 if self.model:
# ---> 75     ids, dimensions, embeddings = self.vectors(documents, buffer)
#      76 else:
#      77     ids = self.ids(documents)
#
# File ~/miniconda3/envs/txtai-env/lib/python3.12/site-packages/txtai/embeddings/index/transform.py:94, in Transform.vectors(self, documents, buffer)
#      82 """
#      83 Runs a vectors transform operation when dense indexing is enabled.
#      84
#    (...)
#      90     (document ids, dimensions, embeddings)
#      91 """
#      93 # Consume stream and transform documents to vectors
# ---> 94 ids, dimensions, batches, stream = self.model.index(self.stream(documents), self.batch)
#      96 # Check that embeddings are available and load as a memmap
#      97 embeddings = None
#
# File ~/miniconda3/envs/txtai-env/lib/python3.12/site-packages/txtai/vectors/base.py:120, in Vectors.index(self, documents, batchsize)
#     118 stream = output.name
#     119 batch = []
# --> 120 for document in documents:
#     121     batch.append(document)
#     123     if len(batch) == batchsize:
#     124         # Convert batch to embeddings
#
# File ~/miniconda3/envs/txtai-env/lib/python3.12/site-packages/txtai/embeddings/index/transform.py:158, in Transform.stream(self, documents)
#     155 batch, offset = [], 0
#     157 # Iterate and process documents stream
# --> 158 for document in documents:
#     159     if isinstance(document[1], dict):
#     160         # Set text field to uid when top-level indexing is disabled and text empty
#     161         if not self.indexing and not document[1].get(self.text):
#
# File ~/miniconda3/envs/txtai-env/lib/python3.12/site-packages/txtai/embeddings/index/stream.py:52, in Stream.__call__(self, documents)
#      49     document = document.get("id"), document, document.get("tags")
#      50 elif isinstance(document, tuple):
#      51     # Create (id, data, tags) tuple
# ---> 52     document = document if len(document) >= 3 else (document[0], document[1], None)
#      53 else:
#      54     # Create (id, data, tags) tuple with empty fields
#      55     document = None, document, None
#
# IndexError: tuple index out of range

# %%
len(embeddings.graph.topics)
# Out:
# 1050

# %%
list(graph.topics.keys())
# Out:
# ['o_de_que_e',
#  'o_que_não_e',
#  'que_de_não_o',
#  'o_que_e_eu',
#  'francos_de_o_que',
#  'l_g',
#  'bordeaux_o_que_de',
#  'du_de_château_loir',
#  'eu_o_que_me',
#  'd',
#  'de_não_que_se',
#  'senhor_jourdan_morin_à',
#  'allan_kardec_caligrafia_atribuída',
#  'lyon_em_de_que',
#  'amélie_minha_tua_carta',
#  'que_de_eu_e',
#  'de_e_os_que',
#  'de_em_que_e',
#  'lyon_que_não_de',
#  'de_o_que_para',
#  'rivail_hldrivail_galileu_reynaud',
#  'volta_de_e_que',
#  'de_pergunta_que_resposta',
#  'o_que_não_eu',
#  'que_de_o_do',
#  'aceite_que_de_o',
#  'logo_não_o_se',
#  'de_paris_1865_janeiro',
#  'de_1865_junho_abril',
#  'que_de_tours_para',
#  'k_moki_ak',
#  'r',
#  'senhora_médium_caussin_ebert',
#  'desliens_senhor_médium______',
#  'lembranças_todos_e_te',
#  'de_outubro_paris_dezembro',
#  'de_sainte_e_para',
#  'e_o_que_um',
#  'e_o_se_que',
#  'ileg_carimbos_i_imperial',
#  '3_2_4_5',
#  'rua_senhor_de_martyrs',
#  'o_que_família_de',
#  's',
#  'muito_bom_h_bem',
#  'sim_resposta_pergunta_você',
#  'rivail_senhor_senhora_paris',
#  'amélie_adeus_boa_tua',
#  'e_o_corpo_que',
#  'que_do_e_de',
#  'e_que_para_o',
#  'que_em_e_o',
#  'e_que_para_de',
#  'que_o_sua_de',
#  'teu_toda_não_todo',
#  'de_que_fatos_em',
#  'que_e_se_de',
#  'paris_de_sociedade_da',
#  '7_8_6_9',
#  '1863_de_paris_dezembro',
#  'p_k',
#  'morte_e_de_que',
#  'que_de_sexta_feira',
#  'guerra_que_não_de',
#  'e_que_de_divina',
#  'corporal_que_é_e',
#  'o_que_e_senhor',
#  'e_da_que_os',
#  'que_senhor_o_não',
#  'e_sua_na__revista_',
#  'allan_kardec_e_afetuoso',
#  'artes_das_e_o',
#  'de_sessão_1866_janeiro',
#  'de_feira_setembro_quinta',
#  'não_que_eu_e',
#  'de_1_setembro_segunda',
#  'amélie_minha_querida_te',
#  'adeus_amigo_meu_bom',
#  'que_girardin_senhor_o',
#  'presidente_e_lincoln_que',
#  'às_e_da_manhã',
#  'davenport_irmãos_os_e',
#  'que_não_de_e',
#  'são_luís_doutor_veja',
#  'alma_de_uma_o',
#  'teatro_e_de_ao',
#  'de_senhor_e_lhe',
#  'muito_que_se_me',
#  'que_não_o_me',
#  'o_caminho_e_de',
#  'de_sociedade_e_do',
#  'senhora_que_de_carta',
#  'eu_não_lhe_que',
#  'de_1864_paris_lyon',
#  'de_cartas_o_e',
#  'de_outubro________________________________________________________________________carimbo',
#  'minha_boa_saúde_que',
#  'e_de_piano_o',
#  'h_hldr',
#  'de_feira_manhã_sexta',
#  'na_jantar_feira_e',
#  'topic_98',
#  'de_4_que_eu',
#  'o_que_espírito_fluido',
#  '_________g___________________________________________',
#  'de_paris_agosto_18',
#  'na_de_não_do',
#  'de_e_da_é',
#  'de_novo_nada_não',
#  'e_o_não_os',
#  'que_se_em_o',
#  'de_paciência_que_uma',
#  'portanto_o_que_foi',
#  'de_receba_senhor_allan',
#  'de_com_o_do',
#  'que_número_o_da',
#  'moral_que_e_de',
#  'com_prazer_o_grande',
#  'um_que_com_mudança',
#  'amélie_boa_minha_adeus',
#  'na_segunda_feira_novos',
#  'o_de_e_do',
#  'félicité_para_e_bem',
#  'de_que_é_se',
#  'presidente_que_martin_o',
#  'fluidos_e_que_espírito',
#  '20_23_24_25',
#  '12_13_14_15',
#  'me_que_dizer_te',
#  'o_e_inferno_de',
#  'de_e_um_é',
#  'humor_mau_o_por',
#  'que_uma_e_é',
#  'minha_chegada_que_e',
#  'são_não_que_me',
#  'bem_que_e_não',
#  'de_que_chefe_e',
#  'que_o_espiritismo_do',
#  'paris_em_o_que',
#  'de_que_e_família',
#  'de_setembro_carimbo_1831',
#  'que_minha_de_carta',
#  'carta_de_me_que',
#  'senhora_e_da_pouco',
#  'que_efeito_o_não',
#  'centro_o_d_______________________________________________________________________',
#  'não_me_e_essa',
#  'para_de_te_não',
#  'de_que_louise_e',
#  'espírito_resposta_espíritos_de',
#  'o_e_ele_que',
#  'pergunta_resposta_que_o',
#  'família_mil_saudações_que',
#  'de_que_se_um',
#  'mais_acolhida_e_que',
#  'feliz_que_em_todos',
#  'francos_o_que_para',
#  '1_muito_que_de',
#  '_______________________________________________________________________de_1860_1861',
#  'age_e_o_espírito',
#  'que_vocês_não_de',
#  'os_e_que_para',
#  'o_senhor_de_e',
#  'que_o_senhor_ele',
#  'lhe_agradeço_e_que',
#  'que_eu_se_dias',
#  'o_que_senhor_um',
#  'que_minha_de_não',
#  'recepção_carimbo_de_2',
#  'eu_disso_ele_e',
#  'e_o_de_em',
#  'o_que_lhe_grato',
#  'que_foi_me_depois',
#  'carta_minha_que_próxima',
#  'de_pergunta_resposta_eles',
#  'tua_carta_me_que',
#  'que_não_e_um',
#  'que_me_e_um',
#  'que_carta_não_senhor',
#  'de_que_vós_e',
#  'o_que_em_senhor',
#  'que_costume_como_o',
#  'do_espiritismo_de_que',
#  'de_e_uma_pessoas',
#  'preciso_é_o_sua',
#  'que_doutrina_de_se',
#  'que_os_em_e',
#  'de_sentimentos_que_lhe',
#  'que_carta_de_uma',
#  'os_que_e_o',
#  'que_o_sido_não',
#  'tempo_do_muito_para',
#  'o_uma_e_que',
#  'progresso_e_o_de',
#  'os_e_visitar_visitantes',
#  'domingo_de_mercado_seguinte',
#  'que_e_em_não',
#  'que_de_não_uma',
#  'se_o_espírito_um',
#  'e_não_cidade_me',
#  'feira_na_eu_quinta',
#  'de_o_feito_tu',
#  'amélie_que_minha_muito',
#  'domingo_o_senhor_uma',
#  'senhor_o_para_também',
#  'o_mas_tempo_tempestade',
#  'o_e_flores_de',
#  'robin_o_senhor_e',
#  'de_médium_que_1864',
#  'de_mediunidade_fluidos_o',
#  'que_o_os_ele',
#  'que_eu_de_o',
#  '↩︎_da',
#  'que_o_para_em',
#  'não_ele_disseram_nada',
#  'minhas_que_materiais_meu',
#  'o_isso_por_me',
#  'que_em_paris_e',
#  'não_apenas_quanto_mas',
#  'que_e_para_caminho',
#  'sentimentos_expressão_meus_distintos',
#  'do_o_que_senhor',
#  'o_que_senhor_com',
#  'não_e_de_mas',
#  'não_vou_las_para',
#  'sábado_me_sobre_que',
#  'senhor_tailleur_médium_e',
#  'o_que_me_de',
#  'diversas_de_ele_ela',
#  'e_que_horas_às',
#  'doutrina_que_o_de',
#  'que_para_se_ainda',
#  'senhor_o_do_sessão',
#  'que_de_e_é',
#  'poderia_e_que_o',
#  'de_certo_um_o',
#  'que_é_não_preciso',
#  'que_de_não_moral',
#  'de_1861_agosto_aix',
#  'motivo_não_de_o',
#  'que_os_propaganda_do',
#  'que_muito_bem_não',
#  'o_não_me_minha',
#  'que_de_número_para',
#  'ademais_de_para_em',
#  'paris_carta_de_sua',
#  'de_que_ao_à',
#  'os_e_se_o',
#  'dos_médiuns__do__o',
#  'o_e_sua_ele',
#  'e_não_carta_se',
#  'o_não_de_uma',
#  'de_que_grupo_receba',
#  'que_em_o_resposta',
#  'que_de_com_união',
#  'o_de_ter_e',
#  'que_o_não_com',
#  'da_animal_e_do',
#  'uma_de_não_e',
#  'm_d',
#  'um_de_qualquer_é',
#  'é_egoísmo_e_para',
#  'muito_ela_não_e',
#  'e_que_mais_com',
#  'minha_minhas_uma_em',
#  'o_do_de_banco',
#  'que_de_não_modo',
#  'em_senhora_ao_ileg',
#  'de_muito_com_contente',
#  'bem_muito_de_mim',
#  'de_e_viagem_me',
#  'te_mais_que_de',
#  'cumprimentos_e_te_mil',
#  'e_que_o_feliz',
#  'médium_senhorita_de_chedeaux',
#  'também_de_perigo_em',
#  'minha_amiga_boa_não',
#  'que_da_de_em',
#  'e_com_me_o',
#  'e_me_que_hotel',
#  'amélie_minha_te_e',
#  'o_senhor_para_de',
#  'que_sinais_de_uma',
#  'para_nota_e_anexo',
#  'o_e_da_panteísmo',
#  'na_jesus_de_como',
#  'carta_havre_o_com',
#  'domingo_para_o_e',
#  'e_que_espíritos_o',
#  'b_ao_sr_receba',
#  'lyon_rua_agosto_carimbo',
#  '_a_para_gênese__conselhos',
#  'hoje_o_para_só',
#  'o_que_e__instrução',
#  'que_o_com_do',
#  'que_em_política_causa',
#  'o_e_senhor_villon',
#  'e_educação_de_da',
#  'amélie_adeus_e_até',
#  'que_do_também_muito',
#  'domingo_à_tu_te',
#  'que_o_e_por',
#  'e_que_eu_para',
#  'não_hoje_para_o',
#  'e_que_o_momento',
#  'chefe_ser_profundo_respeito',
#  'que_senhor_de_carta',
#  'e_de_que_senhor',
#  'gostaria_de_é_do',
#  'não_mais_ninguém_imponho',
#  'e_se_não_que',
#  'muito_que_e_algo',
#  'tribulações_que_e_de',
#  'espiritismo_que_do_se',
#  'senhora_em_o_que',
#  'o_que_e_carta',
#  'espiritismo_que_o_e',
#  'como_progresso_o_que',
#  'o_do_segundo_evangelho',
#  'e_o_1858_espírita_',
#  'acrescentar_que_de_não',
#  'que_por_e_se',
#  'o_e_de_da',
#  'não_um_médium_eu',
#  'senhora_foulon_de_da',
#  'que_carta_senhor_o',
#  'que_minha_de_parte',
#  'e_carta_de_em',
#  'os_todos_todas_em',
#  'casa_de_que_sua',
#  'que_bem_senhor_me',
#  'que_ela_o_de',
#  'resposta_não_e_que',
#  'de_o_terá_meu',
#  'o_e_que_com',
#  'eu_é_não_com',
#  'não_para_te_preciso',
#  'trabalho_e_muito_o',
#  '2_que_um_de',
#  'eu_falar_que_quando',
#  'são_que_os_e',
#  'em_vida_mais_se',
#  'que_não_me_em',
#  'de_e_10_100',
#  'o_que_em_casa',
#  'todos_de_e_os',
#  'amélie_minha_adeus_e',
#  'o_e_que_do',
#  'casa_na_de_está',
#  'que_você_jesuítas_e',
#  'resposta_que_hillaire_é',
#  'isso_que_é_não',
#  'de_e_que_amor',
#  'e_natureza_de_todos',
#  'aqui_ele_é_para',
#  'o_não_que_um',
#  'com_de_beijo_como',
#  'o_não_que_paris',
#  'b_d',
#  'me_que_minha_o',
#  'do_e_com_ele',
#  'amélie_o_um_minha',
#  'o_não_nada_de',
#  'tribunal_de_do_um',
#  'amélie_de_querida_o',
#  'não_que_crimes_e',
#  'eu_e_me_um',
#  'carta_quando_de_se',
#  'senhora_na_me_que',
#  'tua_mãe_sincera_amiga',
#  'que_para_da_festejar',
#  '2_uma_ballet_mas',
#  'te_o_beijo_prazer',
#  'interior_audição_o_de',
#  'coração_tua_de_toda',
#  'que_de_o_há',
#  'de_o_qual_poderias',
#  'lhe_eu_o_por',
#  'para_não_que_do',
#  'de_te_o_meus',
#  'os_pelos_chegados_profetas',
#  'e_um_o_sua',
#  'muito_materiais_esses_de',
#  'veja_pode_se_melhor',
#  'sobretudo_não_se_apresse',
#  'de_que_e_um',
#  'e_que_é_minha',
#  'que_me_não_alongar',
#  'senhora_veio_dias_alguns',
#  'adeus_novamente_e_hypolite',
#  'de_minha_muito_não',
#  'de_se_lo_encarar',
#  'de_é_admissão_carta',
#  'ela_está_série_5º',
#  'de_da_e_que',
#  'não_os_que_espíritos',
#  'espíritos_os_meios_o',
#  'e_que_realizar_em',
#  'que_de_uma_se',
#  'eu_espiritismo_o_e',
#  'espírito_um_eu_não',
#  'minha_eu_e_peço',
#  'eu_em_e_que',
#  'em_melhores_me_eu',
#  'meu_que_uma_me',
#  'escrever_e_de_que',
#  'não_que_outros_nenhuma',
#  'não_e_com_de',
#  'disso_e_também_tudo',
#  'de_que_e_bela',
#  'que_na_uma_em',
#  'e_que_o_muito',
#  'com_de_o_ficar',
#  'eu_que_isso_não',
#  'o_de_não_e',
#  'não_que_eu_se',
#  'que_senhor_de_o',
#  'é_uma_que_ser',
#  'de_14_21_enviado',
#  'e_inteligência_o_que',
#  'e_um_de_em',
#  'de_os_que_esse',
#  'de_submeter_não_um',
#  'sinto_não_mas_outros',
#  'que_de_seu_o',
#  'que_de_e_senhora',
#  'que_é_pessoas_há',
#  'é_que_muito_e',
#  'de_e_minha_com',
#  'e_de_mas_os',
#  'o_fato_de_que',
#  'muito_ao_e_que',
#  'é_e_humanidade_o',
#  'moral_e_de_o',
#  'que_do_homem_e',
#  'em_e_que_na',
#  'como_os_e_que',
#  'e_na_do_o',
#  'e_para_se_assim',
#  'de_não_que_é',
#  'de_muito_não_uma',
#  'o_mas_não_isso',
#  'ela_não_o_para',
#  'não_o_e_nada',
#  'que_então_fazer_o',
#  'não_que_ele_eu',
#  'que_e_uma_do',
#  'não_que_mas_se',
#  'que_não_e_ele',
#  'o_duas_de_bem',
#  'homem_o_de_um',
#  'de_o_que_é',
#  'habitual_seu_com_hum',
#  'e_que_não_do',
#  'os_e_podem_não',
#  'o_que_você_e',
#  'eu_sei_por_é',
#  'o_que_chegar_será',
#  '10_mes10_2_11',
#  'de_casa_senhor_campo',
#  'o_que_e_senhora',
#  'em_sem_se_seu',
#  'de_dia_aix_que',
#  'que_me_e_resultado',
#  'o_ainda_está_tudo',
#  'hoje_à_noite_e',
#  'não_tempo_que_meus',
#  'fazer_que_um_o',
#  'que_não_os_para',
#  'e_que_de_dizer',
#  'também_cidade_poderei_e',
#  'e_casa_que_mallet',
#  'tudo_e_para_de',
#  'não_que_de_cabeça',
#  'para_não_o_se',
#  'excessivamente_da_se_e',
#  'que_em_de_luz',
#  'não_que_3_eu',
#  'de_e_que_portanto',
#  'de_palácio_64r_7',
#  'um_que_sinal_é',
#  'me_ocupações_não_ir',
#  'de_e_à_da',
#  'o_primeiro_com_é',
#  'dos_espíritos_manifestações_fenômenos',
#  'momento_ele_de_nesse',
#  'que_senhor_o_refutar',
#  'que_mais_foi_resultados',
#  'saber_quanto_não_gostaria',
#  'situação_um_o_apresentou',
#  'não_se_quanto_às',
#  'os_e_outros_para',
#  'casa_na_bem_se',
#  'senhor_o_lhe_s',
#  'suas_não_se_coisas',
#  'que_espíritos_começam_libertar',
#  'ele_é_o_não',
#  'que_ou_mais_menos',
#  'de_efeito_e_moral',
#  'que_o_uma_mais',
#  'meu_e_que_do',
#  'o_os_que_para',
#  'e_que_minha_o',
#  'que_de_muito_não',
#  'obra_nova_e_de',
#  'o_que_em_ao',
#  'de_o_que_diga',
#  'não_que_o_pessoas',
#  'não_que_e_na',
#  'em_e_à_doutrina',
#  'não_uma_que_para',
#  'se_de_num_deve',
#  'uma_o_para_certas',
#  'o_os_que_se',
#  'que_de_não_periódica',
#  'espiritismo_que_senhor_coisa',
#  'espiritismo_que_do_em',
#  'que_para_lhe_sabò',
#  'que_na_é_ruína',
#  'senhor_sonnac_em_vincent',
#  'de_e_iniciante_decepções',
#  'mas_não_vista_sem',
#  'que_muito_e_com',
#  'espíritos_se_não_tão',
#  'de_oito_criança_tem',
#  'senhora_que_em_eu',
#  'para_de_em_o',
#  'e_lógica_uma_é',
#  'eu_não_senhor_ainda',
#  'de_e_que_por',
#  'que_de_em_um',
#  'palavra_de_o_uma',
#  'suas_que_e_ela',
#  'que_não_razões_lhe',
#  'e_que_é_os',
#  'e_que_um_se',
#  'é_que_espíritas_seus',
#  'de_com_acontece_todos',
#  'bem_amigo_de_o',
#  'espiritismo_o_sua_um',
#  'e_um_melhor_prefere',
#  'não_meu_que_posto',
#  'de_muito_mas_que',
#  'de_o_não_se',
#  'que_tempo_os_do',
#  'em_e_que_para',
#  'que_com_e_contente',
#  'o_que_da_tempo',
#  'em_não_que_de',
#  'com_o_que_de',
#  'que_minha_para_de',
#  'que_dizer_de_te',
#  'o_casa_que_meu',
#  'que_de_o_tudo',
#  'que_se_cânfora_aloé',
#  'topic_625',
#  'o_bem_há_de',
#  'e_de_pessoas_que',
#  'e_que_mas_essa',
#  'o_os_de_estão',
#  'de_em_o_feira',
#  'não_isso_outros_modo',
#  'um_asseguro_eles_ataque',
#  'eu_o_homens_com',
#  'havia_e_que_luta',
#  'e_dois_ser_deve',
#  'de_setembro_disso_em',
#  'muito_da_atividade_dores',
#  'pergunta_muito_não_parte',
#  'para_de_uma_ao',
#  'e_que_de_momento',
#  'do_que_para_lhe',
#  'eu_o_que_até',
#  'um_uma_e_ser',
#  'e_que_bem_me',
#  'seria_de_que_algo',
#  'à_morte_da_me',
#  'que_não_muito_o',
#  'cada_que_um_ela',
#  'eu_não_indiferente_alguns',
#  'ele_me_hospital_serviço',
#  'vieram_de_em_especialmente',
#  'de_o_ele_lhes',
#  'me_de_um_momento',
#  'em_eu_o_que',
#  'os_para_estavam_teriam',
#  'de_em_o_que',
#  'de_como_assim_crenças',
#  'dias_eu_não_os',
#  'em_seu_de_não',
#  'os_que_se_comê',
#  'dos_portanto_que_do',
#  'de_considerável_homens_que',
#  'senhora_tailleur_e_ele',
#  'o_meu_e_que',
#  'um_agora_alguns_os',
#  'é_para_o_não',
#  'te_espero_eu_beijo',
#  'o_e_há_terra',
#  'uma_em_o_e',
#  'é_se_em_o',
#  'os_e_que_lei',
#  'de_não_local_um',
#  'eis_correspondência_que_canu',
#  'e_não_que_carta',
#  'o_e_de_todos',
#  'estômago_do_com_o',
#  'os_para_o_e',
#  'e_o_que_jantar',
#  'do_de_uma_lyon',
#  'que_o_padre_de',
#  'eu_minha_de_se',
#  'de_segunda_manhã_feira',
#  'que_de_uma_surgiu',
#  'que_para_de_espíritos',
#  'de_sua_casa_porque',
#  'o_e_espírito_seu',
#  'o_espírito_e_que',
#  'que_não_escopo_fica',
#  'eu_não_coisas_das',
#  'nos_de_forma_ajudá',
#  'com_bem_em_muito',
#  'endereço_o_das_e',
#  'um_imediatamente_ouviu_terrível',
#  '_o_tem_livro_dos',
#  'o_e_na_é',
#  'outro_em_lado_não',
#  'não_que_minha_uma',
#  'e_de_embora_neto',
#  'o_não_e_bem',
#  'o_pensamento_e_que',
#  'desperdiçar_não_e_isso',
#  'com_de_se_ser',
#  'eu_com_em_resposta',
#  'que_é_não_ao',
#  'tudo_que_do_senhor',
#  'o_e_que_da',
#  'que_um_preciso_não',
#  'o_senhora_que_seguem',
#  'ou_o_não_fazer',
#  'não_e_é_de',
#  'bem_conselhos_um_nos',
#  'de_se_ácidas_traduz',
#  'não_é_um_de',
#  'que_pequena_bem_não',
#  'não_natural_que_eventos',
#  'tenho_muito_e_para',
#  'd_sic',
#  'não_que_de_me',
#  'o_é_de_como',
#  'pergunta_você_conversou_nos',
#  'e_do_é_para',
#  'de_se_bandeira_nós',
#  'não_pública_que_sessão',
#  'e_que_na_é',
#  'em_humanidade_seu_à',
#  'uma_e_comprovação_é',
#  'muito_não_senhora_que',
#  'e_que_de_me',
#  'entre_em_o_se',
#  'só_podíamos_que_dizer',
#  'de_sem_se_não',
#  'cura_outro_de_o',
#  'anexo_queira_retrato_em',
#  'embora_signatários_la_meu',
#  'topic_740',
#  'topic_741',
#  'topic_742',
#  'topic_743',
#  'topic_744',
#  'topic_745',
#  'topic_746',
#  'topic_747',
#  'topic_748',
#  'topic_749',
#  'topic_750',
#  'topic_751',
#  'topic_752',
#  'topic_753',
#  'topic_754',
#  'topic_755',
#  'topic_756',
#  'topic_757',
#  'topic_758',
#  'topic_759',
#  'topic_760',
#  'topic_761',
#  'topic_762',
#  'topic_763',
#  'topic_764',
#  'topic_765',
#  'topic_766',
#  'topic_767',
#  'topic_768',
#  'topic_769',
#  'topic_770',
#  'topic_771',
#  'topic_772',
#  'topic_773',
#  'topic_774',
#  'topic_775',
#  'topic_776',
#  'topic_777',
#  'resultados_intermédio_espíritos_o',
#  'topic_779',
#  'topic_780',
#  'topic_781',
#  'topic_782',
#  'topic_783',
#  'topic_784',
#  'topic_785',
#  'topic_786',
#  'topic_787',
#  'topic_788',
#  'topic_789',
#  'topic_790',
#  'topic_791',
#  'certas_alguns_o_impressor',
#  'topic_793',
#  'topic_794',
#  'topic_795',
#  'topic_796',
#  'topic_797',
#  'topic_798',
#  'topic_799',
#  'topic_800',
#  'topic_801',
#  'topic_802',
#  'topic_803',
#  'topic_804',
#  'pelo_sensatas_divino_em',
#  'topic_806',
#  'topic_807',
#  'topic_808',
#  'topic_809',
#  'topic_810',
#  'topic_811',
#  'sem_o_será_novos',
#  'topic_813',
#  'também_pelo_em_segunda',
#  'topic_815',
#  'topic_816',
#  'topic_817',
#  'topic_818',
#  'topic_819',
#  'topic_820',
#  'topic_821',
#  'topic_822',
#  'topic_823',
#  'topic_824',
#  'topic_825',
#  'topic_826',
#  'topic_827',
#  'topic_828',
#  'topic_829',
#  'topic_830',
#  'topic_831',
#  'topic_832',
#  'topic_833',
#  'topic_834',
#  'topic_835',
#  'topic_836',
#  'topic_837',
#  'também_em_ou_não',
#  'topic_839',
#  'topic_840',
#  'topic_841',
#  'topic_842',
#  'topic_843',
#  'topic_844',
#  'topic_845',
#  'topic_846',
#  'topic_847',
#  'topic_848',
#  'topic_849',
#  'topic_850',
#  'topic_851',
#  'topic_852',
#  'topic_853',
#  'topic_854',
#  'topic_855',
#  'topic_856',
#  'topic_857',
#  'topic_858',
#  'topic_859',
#  'topic_860',
#  'topic_861',
#  'topic_862',
#  'topic_863',
#  'topic_864',
#  'topic_865',
#  'topic_866',
#  'topic_867',
#  'topic_868',
#  'topic_869',
#  'topic_870',
#  'topic_871',
#  'topic_872',
#  'topic_873',
#  'topic_874',
#  'topic_875',
#  'topic_876',
#  'topic_877',
#  'topic_878',
#  'topic_879',
#  'topic_880',
#  'topic_881',
#  'topic_882',
#  'topic_883',
#  'topic_884',
#  'topic_885',
#  'topic_886',
#  'topic_887',
#  'topic_888',
#  'topic_889',
#  'topic_890',
#  'topic_891',
#  'topic_892',
#  'topic_893',
#  'topic_894',
#  'topic_895',
#  'topic_896',
#  'topic_897',
#  'topic_898',
#  'topic_899',
#  'topic_900',
#  'topic_901',
#  'topic_902',
#  'topic_903',
#  'topic_904',
#  'topic_905',
#  'topic_906',
#  'topic_907',
#  'topic_908',
#  'topic_909',
#  'topic_910',
#  'topic_911',
#  'topic_912',
#  'topic_913',
#  'topic_914',
#  'topic_915',
#  'topic_916',
#  'topic_917',
#  'topic_918',
#  'topic_919',
#  'topic_920',
#  'topic_921',
#  'topic_922',
#  'topic_923',
#  'topic_924',
#  'topic_925',
#  'topic_926',
#  'topic_927',
#  'espíritos_o_meu_os',
#  'topic_929',
#  'topic_930',
#  'topic_931',
#  'topic_932',
#  'topic_933',
#  'topic_934',
#  'topic_935',
#  'topic_936',
#  'topic_937',
#  'topic_938',
#  'topic_939',
#  'topic_940',
#  'topic_941',
#  'topic_942',
#  'topic_943',
#  'topic_944',
#  'topic_945',
#  'topic_946',
#  'entre_não_assumir_encargos',
#  'topic_948',
#  'topic_949',
#  'topic_950',
#  'topic_951',
#  'topic_952',
#  'topic_953',
#  'topic_954',
#  'topic_955',
#  'topic_956',
#  'topic_958',
#  'topic_959',
#  'em_muito_eu_o',
#  'topic_961',
#  'topic_962',
#  'topic_963',
#  'topic_964',
#  'topic_965',
#  'topic_966',
#  'topic_967',
#  'topic_968',
#  'topic_969',
#  'topic_970',
#  'topic_971',
#  'topic_972',
#  'topic_973',
#  'topic_974',
#  'topic_975',
#  'topic_976',
#  'topic_977',
#  'topic_978',
#  'topic_979',
#  'topic_980',
#  'topic_981',
#  'topic_982',
#  'topic_983',
#  'topic_984',
#  'topic_985',
#  'topic_986',
#  'topic_987',
#  'topic_988',
#  'topic_989',
#  'topic_990',
#  'topic_991',
#  'topic_992',
#  'topic_993',
#  'topic_994',
#  'topic_995',
#  'topic_996',
#  'topic_997',
#  'topic_998',
#  'topic_999',
#  'topic_1000',
#  'topic_1001',
#  'topic_1002',
#  'topic_1003',
#  'topic_1004',
#  'topic_1005',
#  'topic_1006',
#  'maldade_dizia_sessão_pergunta',
#  'topic_1008',
#  'topic_1009',
#  'topic_1010',
#  'topic_1011',
#  'topic_1012',
#  'topic_1013',
#  'topic_1014',
#  'topic_1015',
#  'topic_1016',
#  'topic_1017',
#  'topic_1018',
#  'topic_1019',
#  'topic_1020',
#  'topic_1021',
#  'topic_1022',
#  'topic_1023',
#  'topic_1024',
#  'topic_1025',
#  'topic_1026',
#  'topic_1027',
#  'topic_1028',
#  'topic_1029',
#  'topic_1030',
#  'topic_1031',
#  'topic_1032',
#  'topic_1033',
#  'topic_1034',
#  'topic_1035',
#  'topic_1036',
#  'depois_informada_o_ir',
#  'topic_1038',
#  'topic_1039',
#  'topic_1040',
#  'topic_1041',
#  'topic_1042',
#  'topic_1043',
#  'topic_1044',
#  'topic_1045',
#  'topic_1046',
#  'em_espíritos_eu_não',
#  'topic_1048',
#  'topic_1049',
#  'topic_1050',
#  'topic_1051',
#  'topic_1052',
#  'topic_1053',
#  'topic_1054',
#  'desde_início_sessão_da',
#  'topic_1056',
#  'topic_1057',
#  'topic_1058',
#  'topic_1059',
#  'topic_1060',
#  'topic_1061',
#  'topic_1062',
#  'topic_1063',
#  'topic_1064',
#  'topic_1065',
#  'topic_1066',
#  'topic_1067',
#  'topic_1068',
#  'topic_1069',
#  'topic_1070',
#  'topic_1071',
#  'topic_1072',
#  'topic_1073',
#  'topic_1074',
#  'topic_1075',
#  ...]

# %%
for x, topic in enumerate(list(graph.topics.keys())[:5]):
  print(graph.categories[x], topic)
# Out:
# Health o_de_que_e
# Health o_que_não_e
# Society & Culture que_de_não_o
# Health o_que_e_eu
# Society & Culture francos_de_o_que

# %%
print(embeddings.search("select text from txtai where similar('viagem')", 1)[0]["text"])
# Out:
# Fiquei contente em saber que sua viagem aqui “.

# %%
centrality = graph.centrality()

topics = list(graph.topics.keys())

for uid in list(centrality.keys())[:5]:
  topic = graph.attribute(uid, "topic")
  print(f"{topic} ({topics.index(topic)})")
# Out:
# topic_754 (679)
# topic_740 (665)
# topic_743 (668)
# topic_807 (732)
# topic_762 (687)
